# %% [markdown]
# <a href="https://colab.research.google.com/github/Mfr3ak/PyTorch-Practice/blob/PyTorch_Practice_Solutions/extras/exercises/New%20Practice/02_pytorch_classification_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 02. PyTorch Classification Exercises
#
# The following is a template for 02. PyTorch Classification exercises.
#
# It's only starter code and it's your job to fill in the blanks.
#
# Because of the flexibility of PyTorch, there may be more than one way to answer the question.
#
# Don't worry about trying to be *right* just try writing code that suffices the question.
#
# ## Resources
# * These exercises are based on [notebook 02 of the learn PyTorch course](https://www.learnpytorch.io/02_pytorch_classification/).
# * You can see one form of [solutions on GitHub](https://github.com/mrdbourke/pytorch-deep-learning/tree/main/extras/solutions) (but try the exercises below yourself first!).

# %%
# Import torch
import torch

# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"

# Setup random seed
RANDOM_SEED = 42

# %% [markdown]
# ## 1. Make a binary classification dataset with Scikit-Learn's [`make_moons()`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html) function.
#   * For consistency, the dataset should have 1000 samples and a `random_state=42`.
#   * Turn the data into PyTorch tensors.
#   * Split the data into training and test sets using `train_test_split` with 80% training and 20% testing.

# %%
# Create a dataset with Scikit-Learn's make_moons()
from sklearn.datasets import make_moons

# %%
# Turn data into a DataFrame
import pandas as pd

# %%
# Visualize the data on a scatter plot
import matplotlib.pyplot as plt
import torch

# %%
# Turn data into tensors of dtype float
X, y = make_moons(n_samples=1000,
                  noise=0.07,
                  random_state=RANDOM_SEED)

X = torch.from_numpy(X).to(device).type(torch.float)
y = torch.from_numpy(y).to(device).type(torch.float)


# Split the data into train and test sets (80% train, 20% test)
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,shuffle=True)
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([800, 2])
# torch.Size([800])

# %% [markdown]
# ## 2. Build a model by subclassing `nn.Module` that incorporates non-linear activation functions and is capable of fitting the data you created in 1.
#   * Feel free to use any combination of PyTorch layers (linear and non-linear) you want.

# %%
import torch
from torch import nn

# Inherit from nn.Module to make a model capable of fitting the mooon data
from torch import nn
class MoonModelV0(nn.Module):
    ## Your code here ##
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Linear(in_features = 2, out_features=10),
            nn.Linear(in_features=10, out_features = 10),
            nn.ReLU(),
            nn.Linear(in_features=10, out_features = 1)
        )

    def forward(self, x):
        ## Your code here ##
        return self.layer1(x)

# Instantiate the model
## Your code here ##
model = MoonModelV0().to(device)

# %% [markdown]
# ## 3. Setup a binary classification compatible loss function and optimizer to use when training the model built in 2.

# %%
# Setup loss function
loss_fn = nn.BCEWithLogitsLoss()

# Setup optimizer to optimize model's parameters
optimizer = torch.optim.SGD(params = model.parameters(), lr = 0.1)

# %% [markdown]
# ## 4. Create a training and testing loop to fit the model you created in 2 to the data you created in 1.
#   * Do a forward pass of the model to see what's coming out in the form of logits, prediction probabilities and labels.
#   * To measure model accuray, you can create your own accuracy function or use the accuracy function in [TorchMetrics](https://torchmetrics.readthedocs.io/en/latest/).
#   * Train the model for long enough for it to reach over 96% accuracy.
#   * The training loop should output progress every 10 epochs of the model's training and test set loss and accuracy.

# %%
# What's coming out of our model?
logits = model(X_train[0])

# logits (raw outputs of model)
print(f"Logits: {logits}")
## Your code here ##

# Prediction probabilities
## Your code here ##
probs = torch.sigmoid(logits)
print(f"Pred probs:{probs}")

# Prediction labels
## Your code here ##
labels = torch.round(probs)
print(f"Pred labels:{labels}")
# Out:
# Logits: tensor([0.1872], device='cuda:0', grad_fn=<ViewBackward0>)
# Pred probs:tensor([0.5467], device='cuda:0', grad_fn=<SigmoidBackward0>)
# Pred labels:tensor([1.], device='cuda:0', grad_fn=<RoundBackward0>)

# %%
# Let's calculuate the accuracy using accuracy from TorchMetrics
# !pip -q install torchmetrics # Colab doesn't come with torchmetrics
from torchmetrics import Accuracy

## TODO: Uncomment this code to use the Accuracy function
acc_fn = Accuracy(task="multiclass", num_classes=2).to(device) # send accuracy function to device
acc_fn
# Out:
# MulticlassAccuracy()

# %%
## TODO: Uncomment this to set the seed
torch.manual_seed(RANDOM_SEED)

# Setup epochs
epochs = 10000

# Send data to the device
X_train = X_train.to(device)
y_train = y_train.to(device)
X_test = X_test.to(device)
y_test = y_test.to(device)

# Loop through the data
for epoch in range(epochs):
  ### Training
  model.train()


  # 1. Forward pass (logits output)
  y_logits = model(X_train)
  y_logits = y_logits.squeeze()

  # Turn logits into prediction probabilities
  y_prob = torch.sigmoid(y_logits)


  # Turn prediction probabilities into prediction labels
  y_pred = torch.round(y_prob)


  # 2. Calculaute the loss
  loss = loss_fn(y_logits, y_train) # loss = compare model raw outputs to desired model outputs

  # Calculate the accuracy
  acc = acc_fn(y_pred, y_train.int()) # the accuracy function needs to compare pred labels (not logits) with actual labels

  # 3. Zero the gradients
  optimizer.zero_grad()


  # 4. Loss backward (perform backpropagation) - https://brilliant.org/wiki/backpropagation/#:~:text=Backpropagation%2C%20short%20for%20%22backward%20propagation,to%20the%20neural%20network's%20weights.
  loss.backward()

  # 5. Step the optimizer (gradient descent) - https://towardsdatascience.com/gradient-descent-algorithm-a-deep-dive-cf04e8115f21#:~:text=Gradient%20descent%20(GD)%20is%20an,e.g.%20in%20a%20linear%20regression)
  optimizer.step()


  ### Testing
  model.eval()
  with torch.inference_mode():
    # 1. Forward pass (to get the logits)
    y_pred_logits = model(X_test)
    y_pred_logits = y_pred_logits.squeeze()

    # Turn the test logits into prediction labels
    y_pred_probs = torch.sigmoid(y_pred_logits)
    y_pred_labels = torch.round((y_pred_probs))


    # 2. Caculate the test loss/acc
    loss_test = loss_fn(y_pred_logits, y_test)
    acc_test = acc_fn(y_pred_labels, y_test.int())

  # Print out what's happening every 100 epochs
  if epoch % 100 == 0:
    print(f"Epoch # : {epoch} \n Training loss : {loss} & Training Accuracy : {acc} \n Testing Loss : {loss_test} & Testing Accuracy : {acc_test}")
# Out:
# Epoch # : 0
#  Training loss : 0.20667071640491486 & Training Accuracy : 0.9075000286102295
#  Testing Loss : 0.27167701721191406 & Testing Accuracy : 0.8650000095367432
# Epoch # : 100
#  Training loss : 0.20060385763645172 & Training Accuracy : 0.9100000262260437
#  Testing Loss : 0.2698787748813629 & Testing Accuracy : 0.8600000143051147
# Epoch # : 200
#  Training loss : 0.19617396593093872 & Training Accuracy : 0.9112499952316284
#  Testing Loss : 0.26925724744796753 & Testing Accuracy : 0.8700000047683716
# Epoch # : 300
#  Training loss : 0.192825585603714 & Training Accuracy : 0.9100000262260437
#  Testing Loss : 0.26869630813598633 & Testing Accuracy : 0.8650000095367432
# Epoch # : 400
#  Training loss : 0.18935976922512054 & Training Accuracy : 0.9087499976158142
#  Testing Loss : 0.26667824387550354 & Testing Accuracy : 0.8700000047683716
# Epoch # : 500
#  Training loss : 0.18393942713737488 & Training Accuracy : 0.9112499952316284
#  Testing Loss : 0.2607834041118622 & Testing Accuracy : 0.8700000047683716
# Epoch # : 600
#  Training loss : 0.17389532923698425 & Training Accuracy : 0.918749988079071
#  Testing Loss : 0.24784044921398163 & Testing Accuracy : 0.8700000047683716
# Epoch # : 700
#  Training loss : 0.1556013524532318 & Training Accuracy : 0.9275000095367432
#  Testing Loss : 0.22311149537563324 & Testing Accuracy : 0.8899999856948853
# Epoch # : 800
#  Training loss : 0.1276785284280777 & Training Accuracy : 0.9437500238418579
#  Testing Loss : 0.18394388258457184 & Testing Accuracy : 0.9100000262260437
# Epoch # : 900
#  Training loss : 0.09693308919668198 & Training Accuracy : 0.9649999737739563
#  Testing Loss : 0.1393546313047409 & Testing Accuracy : 0.9300000071525574
# Epoch # : 1000
#  Training loss : 0.0709223672747612 & Training Accuracy : 0.981249988079071
#  Testing Loss : 0.10191785544157028 & Testing Accuracy : 0.949999988079071
# Epoch # : 1100
#  Training loss : 0.05197124183177948 & Training Accuracy : 0.9912499785423279
#  Testing Loss : 0.07541637122631073 & Testing Accuracy : 0.9800000190734863
# Epoch # : 1200
#  Training loss : 0.03919832780957222 & Training Accuracy : 0.9962499737739563
#  Testing Loss : 0.057555053383111954 & Testing Accuracy : 0.9900000095367432
# Epoch # : 1300
#  Training loss : 0.03059305064380169 & Training Accuracy : 0.9975000023841858
#  Testing Loss : 0.04588713496923447 & Testing Accuracy : 0.9900000095367432
# Epoch # : 1400
#  Training loss : 0.02464505098760128 & Training Accuracy : 0.9975000023841858
#  Testing Loss : 0.037955332547426224 & Testing Accuracy : 0.9900000095367432
# Epoch # : 1500
#  Training loss : 0.02039848268032074 & Training Accuracy : 0.9987499713897705
#  Testing Loss : 0.03239530324935913 & Testing Accuracy : 0.9950000047683716
# Epoch # : 1600
#  Training loss : 0.017269587144255638 & Training Accuracy : 1.0
#  Testing Loss : 0.02818816527724266 & Testing Accuracy : 0.9950000047683716
# Epoch # : 1700
#  Training loss : 0.014889726415276527 & Training Accuracy : 1.0
#  Testing Loss : 0.025045126676559448 & Testing Accuracy : 0.9950000047683716
# Epoch # : 1800
#  Training loss : 0.013037307187914848 & Training Accuracy : 1.0
#  Testing Loss : 0.02259199135005474 & Testing Accuracy : 0.9950000047683716
# Epoch # : 1900
#  Training loss : 0.011561034247279167 & Training Accuracy : 1.0
#  Testing Loss : 0.020652327686548233 & Testing Accuracy : 0.9950000047683716
# Epoch # : 2000
#  Training loss : 0.010359185747802258 & Training Accuracy : 1.0
#  Testing Loss : 0.019093122333288193 & Testing Accuracy : 0.9950000047683716
# Epoch # : 2100
#  Training loss : 0.00935377087444067 & Training Accuracy : 1.0
#  Testing Loss : 0.017830802127718925 & Testing Accuracy : 0.9950000047683716
# Epoch # : 2200
#  Training loss : 0.00851456169039011 & Training Accuracy : 1.0
#  Testing Loss : 0.016736922785639763 & Testing Accuracy : 0.9950000047683716
# Epoch # : 2300
#  Training loss : 0.0078033944591879845 & Training Accuracy : 1.0
#  Testing Loss : 0.01582200638949871 & Testing Accuracy : 0.9950000047683716
# Epoch # : 2400
#  Training loss : 0.007193384226411581 & Training Accuracy : 1.0
#  Testing Loss : 0.015044682659208775 & Testing Accuracy : 0.9950000047683716
# Epoch # : 2500
#  Training loss : 0.0066648912616074085 & Training Accuracy : 1.0
#  Testing Loss : 0.014369366690516472 & Testing Accuracy : 0.9950000047683716
# Epoch # : 2600
#  Training loss : 0.006202897988259792 & Training Accuracy : 1.0
#  Testing Loss : 0.013768997974693775 & Testing Accuracy : 0.9950000047683716
# Epoch # : 2700
#  Training loss : 0.0057957409881055355 & Training Accuracy : 1.0
#  Testing Loss : 0.013248921371996403 & Testing Accuracy : 0.9950000047683716
# Epoch # : 2800
#  Training loss : 0.005434228107333183 & Training Accuracy : 1.0
#  Testing Loss : 0.012791638262569904 & Testing Accuracy : 0.9950000047683716
# Epoch # : 2900
#  Training loss : 0.005111845675855875 & Training Accuracy : 1.0
#  Testing Loss : 0.01237596943974495 & Testing Accuracy : 0.9950000047683716
# Epoch # : 3000
#  Training loss : 0.004822715651243925 & Training Accuracy : 1.0
#  Testing Loss : 0.011993149295449257 & Testing Accuracy : 0.9950000047683716
# Epoch # : 3100
#  Training loss : 0.004562066402286291 & Training Accuracy : 1.0
#  Testing Loss : 0.011651611886918545 & Testing Accuracy : 0.9950000047683716
# Epoch # : 3200
#  Training loss : 0.004325965419411659 & Training Accuracy : 1.0
#  Testing Loss : 0.011345431208610535 & Testing Accuracy : 0.9950000047683716
# Epoch # : 3300
#  Training loss : 0.004111190792173147 & Training Accuracy : 1.0
#  Testing Loss : 0.011064744554460049 & Testing Accuracy : 0.9950000047683716
# Epoch # : 3400
#  Training loss : 0.003914989065378904 & Training Accuracy : 1.0
#  Testing Loss : 0.010809418745338917 & Testing Accuracy : 0.9950000047683716
# Epoch # : 3500
#  Training loss : 0.00373524846509099 & Training Accuracy : 1.0
#  Testing Loss : 0.01057505700737238 & Testing Accuracy : 0.9950000047683716
# Epoch # : 3600
#  Training loss : 0.00357000227086246 & Training Accuracy : 1.0
#  Testing Loss : 0.010362161323428154 & Testing Accuracy : 0.9950000047683716
# Epoch # : 3700
#  Training loss : 0.003417634405195713 & Training Accuracy : 1.0
#  Testing Loss : 0.010167624801397324 & Testing Accuracy : 0.9950000047683716
# Epoch # : 3800
#  Training loss : 0.0032767432276159525 & Training Accuracy : 1.0
#  Testing Loss : 0.009985389187932014 & Testing Accuracy : 0.9950000047683716
# Epoch # : 3900
#  Training loss : 0.0031461070757359266 & Training Accuracy : 1.0
#  Testing Loss : 0.009815721772611141 & Testing Accuracy : 0.9950000047683716
# Epoch # : 4000
#  Training loss : 0.0030246940441429615 & Training Accuracy : 1.0
#  Testing Loss : 0.009660228155553341 & Testing Accuracy : 0.9950000047683716
# Epoch # : 4100
#  Training loss : 0.002911550924181938 & Training Accuracy : 1.0
#  Testing Loss : 0.009512444026768208 & Testing Accuracy : 0.9950000047683716
# Epoch # : 4200
#  Training loss : 0.002805911237373948 & Training Accuracy : 1.0
#  Testing Loss : 0.009377343580126762 & Testing Accuracy : 0.9950000047683716
# Epoch # : 4300
#  Training loss : 0.0027070348151028156 & Training Accuracy : 1.0
#  Testing Loss : 0.009249097667634487 & Testing Accuracy : 0.9950000047683716
# Epoch # : 4400
#  Training loss : 0.002614390105009079 & Training Accuracy : 1.0
#  Testing Loss : 0.009128996171057224 & Testing Accuracy : 0.9950000047683716
# Epoch # : 4500
#  Training loss : 0.002527395496144891 & Training Accuracy : 1.0
#  Testing Loss : 0.009018509648740292 & Testing Accuracy : 0.9950000047683716
# Epoch # : 4600
#  Training loss : 0.0024455550592392683 & Training Accuracy : 1.0
#  Testing Loss : 0.00891288835555315 & Testing Accuracy : 0.9950000047683716
# Epoch # : 4700
#  Training loss : 0.0023684329353272915 & Training Accuracy : 1.0
#  Testing Loss : 0.008814717642962933 & Testing Accuracy : 0.9950000047683716
# Epoch # : 4800
#  Training loss : 0.0022956542670726776 & Training Accuracy : 1.0
#  Testing Loss : 0.00872065033763647 & Testing Accuracy : 0.9950000047683716
# Epoch # : 4900
#  Training loss : 0.002226876327767968 & Training Accuracy : 1.0
#  Testing Loss : 0.008632105775177479 & Testing Accuracy : 0.9950000047683716
# Epoch # : 5000
#  Training loss : 0.002161798533052206 & Training Accuracy : 1.0
#  Testing Loss : 0.008548702113330364 & Testing Accuracy : 0.9950000047683716
# Epoch # : 5100
#  Training loss : 0.0021001286804676056 & Training Accuracy : 1.0
#  Testing Loss : 0.00846836343407631 & Testing Accuracy : 0.9950000047683716
# Epoch # : 5200
#  Training loss : 0.0020416134502738714 & Training Accuracy : 1.0
#  Testing Loss : 0.008395249955356121 & Testing Accuracy : 0.9950000047683716
# Epoch # : 5300
#  Training loss : 0.0019860216416418552 & Training Accuracy : 1.0
#  Testing Loss : 0.008323563262820244 & Testing Accuracy : 0.9950000047683716
# Epoch # : 5400
#  Training loss : 0.0019331448711454868 & Training Accuracy : 1.0
#  Testing Loss : 0.008255920372903347 & Testing Accuracy : 0.9950000047683716
# Epoch # : 5500
#  Training loss : 0.0018827912863343954 & Training Accuracy : 1.0
#  Testing Loss : 0.008191998116672039 & Testing Accuracy : 0.9950000047683716
# Epoch # : 5600
#  Training loss : 0.0018347961595281959 & Training Accuracy : 1.0
#  Testing Loss : 0.008130008354783058 & Testing Accuracy : 0.9950000047683716
# Epoch # : 5700
#  Training loss : 0.0017890158342197537 & Training Accuracy : 1.0
#  Testing Loss : 0.008071152493357658 & Testing Accuracy : 0.9950000047683716
# Epoch # : 5800
#  Training loss : 0.0017452915199100971 & Training Accuracy : 1.0
#  Testing Loss : 0.00801528338342905 & Testing Accuracy : 0.9950000047683716
# Epoch # : 5900
#  Training loss : 0.0017034924821928144 & Training Accuracy : 1.0
#  Testing Loss : 0.007961455732584 & Testing Accuracy : 0.9950000047683716
# Epoch # : 6000
#  Training loss : 0.0016635050997138023 & Training Accuracy : 1.0
#  Testing Loss : 0.007910147309303284 & Testing Accuracy : 0.9950000047683716
# Epoch # : 6100
#  Training loss : 0.001625212375074625 & Training Accuracy : 1.0
#  Testing Loss : 0.007861205376684666 & Testing Accuracy : 0.9950000047683716
# Epoch # : 6200
#  Training loss : 0.0015885106986388564 & Training Accuracy : 1.0
#  Testing Loss : 0.007814427837729454 & Testing Accuracy : 0.9950000047683716
# Epoch # : 6300
#  Training loss : 0.0015533072873950005 & Training Accuracy : 1.0
#  Testing Loss : 0.007769086863845587 & Testing Accuracy : 0.9950000047683716
# Epoch # : 6400
#  Training loss : 0.0015195185551419854 & Training Accuracy : 1.0
#  Testing Loss : 0.007727600634098053 & Testing Accuracy : 0.9950000047683716
# Epoch # : 6500
#  Training loss : 0.0014870520681142807 & Training Accuracy : 1.0
#  Testing Loss : 0.007685798220336437 & Testing Accuracy : 0.9950000047683716
# Epoch # : 6600
#  Training loss : 0.0014558410039171576 & Training Accuracy : 1.0
#  Testing Loss : 0.007645693141967058 & Testing Accuracy : 0.9950000047683716
# Epoch # : 6700
#  Training loss : 0.0014258199371397495 & Training Accuracy : 1.0
#  Testing Loss : 0.0076086996123194695 & Testing Accuracy : 0.9950000047683716
# Epoch # : 6800
#  Training loss : 0.0013969189021736383 & Training Accuracy : 1.0
#  Testing Loss : 0.007571182679384947 & Testing Accuracy : 0.9950000047683716
# Epoch # : 6900
#  Training loss : 0.0013690725900232792 & Training Accuracy : 1.0
#  Testing Loss : 0.007536767050623894 & Testing Accuracy : 0.9950000047683716
# Epoch # : 7000
#  Training loss : 0.0013422397896647453 & Training Accuracy : 1.0
#  Testing Loss : 0.007502905558794737 & Testing Accuracy : 0.9950000047683716
# Epoch # : 7100
#  Training loss : 0.001316359150223434 & Training Accuracy : 1.0
#  Testing Loss : 0.007470224983990192 & Testing Accuracy : 0.9950000047683716
# Epoch # : 7200
#  Training loss : 0.0012913859682157636 & Training Accuracy : 1.0
#  Testing Loss : 0.007438252214342356 & Testing Accuracy : 0.9950000047683716
# Epoch # : 7300
#  Training loss : 0.0012672730954363942 & Training Accuracy : 1.0
#  Testing Loss : 0.007407373748719692 & Testing Accuracy : 0.9950000047683716
# Epoch # : 7400
#  Training loss : 0.0012439757119864225 & Training Accuracy : 1.0
#  Testing Loss : 0.0073786270804703236 & Testing Accuracy : 0.9950000047683716
# Epoch # : 7500
#  Training loss : 0.001221457147039473 & Training Accuracy : 1.0
#  Testing Loss : 0.007351154927164316 & Testing Accuracy : 0.9950000047683716
# Epoch # : 7600
#  Training loss : 0.0011996785178780556 & Training Accuracy : 1.0
#  Testing Loss : 0.0073247430846095085 & Testing Accuracy : 0.9950000047683716
# Epoch # : 7700
#  Training loss : 0.0011786079267039895 & Training Accuracy : 1.0
#  Testing Loss : 0.0072992900386452675 & Testing Accuracy : 0.9950000047683716
# Epoch # : 7800
#  Training loss : 0.0011582060251384974 & Training Accuracy : 1.0
#  Testing Loss : 0.007274871692061424 & Testing Accuracy : 0.9950000047683716
# Epoch # : 7900
#  Training loss : 0.0011384469689801335 & Training Accuracy : 1.0
#  Testing Loss : 0.007250551600009203 & Testing Accuracy : 0.9950000047683716
# Epoch # : 8000
#  Training loss : 0.0011193070095032454 & Training Accuracy : 1.0
#  Testing Loss : 0.007227884139865637 & Testing Accuracy : 0.9950000047683716
# Epoch # : 8100
#  Training loss : 0.0011007498251274228 & Training Accuracy : 1.0
#  Testing Loss : 0.007205882575362921 & Testing Accuracy : 0.9950000047683716
# Epoch # : 8200
#  Training loss : 0.0010827508522197604 & Training Accuracy : 1.0
#  Testing Loss : 0.007184667978435755 & Testing Accuracy : 0.9950000047683716
# Epoch # : 8300
#  Training loss : 0.0010652877390384674 & Training Accuracy : 1.0
#  Testing Loss : 0.00716308644041419 & Testing Accuracy : 0.9950000047683716
# Epoch # : 8400
#  Training loss : 0.0010483424412086606 & Training Accuracy : 1.0
#  Testing Loss : 0.007142269052565098 & Testing Accuracy : 0.9950000047683716
# Epoch # : 8500
#  Training loss : 0.0010318870190531015 & Training Accuracy : 1.0
#  Testing Loss : 0.007122436072677374 & Testing Accuracy : 0.9950000047683716
# Epoch # : 8600
#  Training loss : 0.0010159043595194817 & Training Accuracy : 1.0
#  Testing Loss : 0.007103271782398224 & Testing Accuracy : 0.9950000047683716
# Epoch # : 8700
#  Training loss : 0.0010003700153902173 & Training Accuracy : 1.0
#  Testing Loss : 0.007084802258759737 & Testing Accuracy : 0.9950000047683716
# Epoch # : 8800
#  Training loss : 0.0009852737421169877 & Training Accuracy : 1.0
#  Testing Loss : 0.007066858466714621 & Testing Accuracy : 0.9950000047683716
# Epoch # : 8900
#  Training loss : 0.0009705862030386925 & Training Accuracy : 1.0
#  Testing Loss : 0.007049602922052145 & Testing Accuracy : 0.9950000047683716
# Epoch # : 9000
#  Training loss : 0.0009563027997501194 & Training Accuracy : 1.0
#  Testing Loss : 0.007032834924757481 & Testing Accuracy : 0.9950000047683716
# Epoch # : 9100
#  Training loss : 0.0009424005984328687 & Training Accuracy : 1.0
#  Testing Loss : 0.007016539573669434 & Testing Accuracy : 0.9950000047683716
# Epoch # : 9200
#  Training loss : 0.0009288689470849931 & Training Accuracy : 1.0
#  Testing Loss : 0.007000881712883711 & Testing Accuracy : 0.9950000047683716
# Epoch # : 9300
#  Training loss : 0.0009156931773759425 & Training Accuracy : 1.0
#  Testing Loss : 0.006985662970691919 & Testing Accuracy : 0.9950000047683716
# Epoch # : 9400
#  Training loss : 0.0009028559434227645 & Training Accuracy : 1.0
#  Testing Loss : 0.006970634218305349 & Testing Accuracy : 0.9950000047683716
# Epoch # : 9500
#  Training loss : 0.0008903474663384259 & Training Accuracy : 1.0
#  Testing Loss : 0.006956184282898903 & Testing Accuracy : 0.9950000047683716
# Epoch # : 9600
#  Training loss : 0.0008781562792137265 & Training Accuracy : 1.0
#  Testing Loss : 0.006942270789295435 & Testing Accuracy : 0.9950000047683716
# Epoch # : 9700
#  Training loss : 0.0008662670152261853 & Training Accuracy : 1.0
#  Testing Loss : 0.006928637623786926 & Testing Accuracy : 0.9950000047683716
# Epoch # : 9800
#  Training loss : 0.0008546740864403546 & Training Accuracy : 1.0
#  Testing Loss : 0.00691547617316246 & Testing Accuracy : 0.9950000047683716
# Epoch # : 9900
#  Training loss : 0.0008433672483079135 & Training Accuracy : 1.0
#  Testing Loss : 0.006902710068970919 & Testing Accuracy : 0.9950000047683716

# %% [markdown]
# ## 5. Make predictions with your trained model and plot them using the `plot_decision_boundary()` function created in this notebook.

# %%
# Plot the model predictions
import numpy as np

def plot_decision_boundary(model, X, y):

    # Put everything to CPU (works better with NumPy + Matplotlib)
    model.to("cpu")
    X, y = X.to("cpu"), y.to("cpu")

    # Source - https://madewithml.com/courses/foundations/neural-networks/
    # (with modifications)
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 101),
                         np.linspace(y_min, y_max, 101))

    # Make features
    X_to_pred_on = torch.from_numpy(np.column_stack((xx.ravel(), yy.ravel()))).float()

    # Make predictions
    model.eval()
    with torch.inference_mode():
        y_logits = model(X_to_pred_on)

    # Test for multi-class or binary and adjust logits to prediction labels
    if len(torch.unique(y)) > 2:
        y_pred = torch.softmax(y_logits, dim=1).argmax(dim=1) # mutli-class
    else:
        y_pred = torch.round(torch.sigmoid(y_logits)) # binary

    # Reshape preds and plot
    y_pred = y_pred.reshape(xx.shape).detach().numpy()
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
# Plot decision boundaries for training and test sets
plot_decision_boundary(model, X_train, y_train)

# %%
plot_decision_boundary(model, X_test, y_test)

# %% [markdown]
# ## 6. Replicate the Tanh (hyperbolic tangent) activation function in pure PyTorch.
#   * Feel free to reference the [ML cheatsheet website](https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html#tanh) for the formula.

# %%
# Create a straight line tensor
test_tensor = torch.arange(0,1,0.1)

# %%
# Test torch.tanh() on the tensor and plot it

# %%
# Replicate torch.tanh() and plot it

# %% [markdown]
# ## 7. Create a multi-class dataset using the [spirals data creation function from CS231n](https://cs231n.github.io/neural-networks-case-study/) (see below for the code).
#   * Split the data into training and test sets (80% train, 20% test) as well as turn it into PyTorch tensors.
#   * Construct a model capable of fitting the data (you may need a combination of linear and non-linear layers).
#   * Build a loss function and optimizer capable of handling multi-class data (optional extension: use the Adam optimizer instead of SGD, you may have to experiment with different values of the learning rate to get it working).
#   * Make a training and testing loop for the multi-class data and train a model on it to reach over 95% testing accuracy (you can use any accuracy measuring function here that you like) - 1000 epochs should be plenty.
#   * Plot the decision boundaries on the spirals dataset from your model predictions, the `plot_decision_boundary()` function should work for this dataset too.

# %%
# Code for creating a spiral dataset from CS231n
import numpy as np
import matplotlib.pyplot as plt
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D)) # data matrix (each row = single example)
y = np.zeros(N*K, dtype='uint8') # class labels
for j in range(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.0,1,N) # radius
  t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
  X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
  y[ix] = j
# lets visualize the data
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
plt.show()

# %%
# Turn data into tensors
import torch
X = torch.from_numpy(X).type(torch.float) # features as float32
y = torch.from_numpy(y).type(torch.LongTensor) # labels need to be of type long

# Create train and test splits
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, shuffle = True)
print(f"X_train : {X_train.shape}")
print(f"y_train : {y_train.shape}")
# Out:
# X_train : torch.Size([240, 2])
# y_train : torch.Size([240])

# %%
# Let's calculuate the accuracy for when we fit our model
# !pip -q install torchmetrics # colab doesn't come with torchmetrics
from torchmetrics import Accuracy

## TODO: uncomment the two lines below to send the accuracy function to the device
acc_fn = Accuracy(task="multiclass", num_classes=3).to(device)
acc_fn
# Out:
# MulticlassAccuracy()

# %%
# Prepare device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"

# Create model by subclassing nn.Module
class model_1(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(in_features = 2, out_features = 10),
            nn.Linear(in_features = 10, out_features = 10),
            nn.ReLU(),
            nn.Linear(in_features = 10, out_features = 3)
        )
    def forward(self,X):
        return self.layers(X)

# Instantiate model and send it to device
model_1 = model_1().to(device)

# %%
# Setup data to be device agnostic
X_train, X_test = X_train.to(device), X_test.to(device)
y_train, y_test = y_train.to(device), y_test.to(device)

# Print out first 10 untrained model outputs (forward pass)
print("Logits:")
## Your code here ##
logits = model_1(X_train[:10])
print(logits)

print("Pred probs:")
## Your code here ##
probs = torch.softmax(logits,dim = 1)
print(probs)

print("Pred labels:")
## Your code here ##
preds = torch.argmax(probs, dim = 1)
print(preds)
# Out:
# Logits:
# tensor([[-0.2120, -0.0903,  0.0964],
#         [-0.1823, -0.0534,  0.0897],
#         [-0.2363, -0.1409,  0.1413],
#         [-0.2055, -0.0835,  0.0910],
#         [-0.1773, -0.0881,  0.1101],
#         [-0.1781, -0.0909,  0.2421],
#         [-0.2199, -0.1204,  0.0877],
#         [-0.2487, -0.1732,  0.0861],
#         [-0.1480, -0.0245,  0.1419],
#         [-0.2135, -0.1177,  0.1704]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Pred probs:
# tensor([[0.2865, 0.3235, 0.3900],
#         [0.2898, 0.3297, 0.3804],
#         [0.2810, 0.3091, 0.4099],
#         [0.2878, 0.3251, 0.3871],
#         [0.2919, 0.3191, 0.3890],
#         [0.2767, 0.3020, 0.4213],
#         [0.2886, 0.3188, 0.3926],
#         [0.2877, 0.3102, 0.4021],
#         [0.2884, 0.3263, 0.3853],
#         [0.2802, 0.3084, 0.4114]], device='cuda:0', grad_fn=<SoftmaxBackward0>)
# Pred labels:
# tensor([2, 2, 2, 2, 2, 2, 2, 2, 2, 2], device='cuda:0')

# %%
# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params = model_1.parameters(), lr = 0.1)

# %%
# Build a training loop for the model
epochs = 1000
for epoch in range(epochs):
# Loop over data


  ## Training
  model_1.train()

  # 1. Forward pass
  model_train_preds = model_1(X_train)


  # 2. Calculate the loss
  train_loss = loss_fn(model_train_preds, y_train)


  # 3. Optimizer zero grad
  optimizer.zero_grad()


  # 4. Loss backward
  train_loss.backward()


  # 5. Optimizer step
  optimizer.step()


  ## Testing
  model_1.eval()
  with torch.inference_mode():


    # 1. Forward pass
    model_test_preds = model_1(X_test)

    # 2. Caculate loss and acc
    test_loss = loss_fn(model_test_preds, y_test)
    acc = acc_fn(model_test_preds, y_test)

  # Print out what's happening every 100 epochs
  if epoch%100 == 0:
    print(f"Epoch # : {epoch} \n Training loss : {loss} & Training Accuracy : {acc} \n Testing Loss : {loss_test} & Testing Accuracy : {acc_test}")
# Out:
# Epoch # : 0
#  Training loss : 0.0008324369555339217 & Training Accuracy : 0.75
#  Testing Loss : 0.006890424527227879 & Testing Accuracy : 0.9950000047683716
# Epoch # : 100
#  Training loss : 0.0008324369555339217 & Training Accuracy : 0.949999988079071
#  Testing Loss : 0.006890424527227879 & Testing Accuracy : 0.9950000047683716
# Epoch # : 200
#  Training loss : 0.0008324369555339217 & Training Accuracy : 1.0
#  Testing Loss : 0.006890424527227879 & Testing Accuracy : 0.9950000047683716
# Epoch # : 300
#  Training loss : 0.0008324369555339217 & Training Accuracy : 1.0
#  Testing Loss : 0.006890424527227879 & Testing Accuracy : 0.9950000047683716
# Epoch # : 400
#  Training loss : 0.0008324369555339217 & Training Accuracy : 1.0
#  Testing Loss : 0.006890424527227879 & Testing Accuracy : 0.9950000047683716
# Epoch # : 500
#  Training loss : 0.0008324369555339217 & Training Accuracy : 1.0
#  Testing Loss : 0.006890424527227879 & Testing Accuracy : 0.9950000047683716
# Epoch # : 600
#  Training loss : 0.0008324369555339217 & Training Accuracy : 1.0
#  Testing Loss : 0.006890424527227879 & Testing Accuracy : 0.9950000047683716
# Epoch # : 700
#  Training loss : 0.0008324369555339217 & Training Accuracy : 1.0
#  Testing Loss : 0.006890424527227879 & Testing Accuracy : 0.9950000047683716
# Epoch # : 800
#  Training loss : 0.0008324369555339217 & Training Accuracy : 1.0
#  Testing Loss : 0.006890424527227879 & Testing Accuracy : 0.9950000047683716
# Epoch # : 900
#  Training loss : 0.0008324369555339217 & Training Accuracy : 1.0
#  Testing Loss : 0.006890424527227879 & Testing Accuracy : 0.9950000047683716

# %%
# Plot decision boundaries for training and test sets
plot_decision_boundary(model_1, X_train, y_train)

# %%
plot_decision_boundary(model_1, X_test, y_test)
